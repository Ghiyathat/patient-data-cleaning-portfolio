# %%
import pandas as pd
import numpy as np
from dateutil import parser

# %%
# Load file
df = pd.read_excel("Messy Patient Data.xlsx")
df
# Out:
#     Patient_ID         Name  Age  Gender    Date_of_Admission  \
# 0      PID1000    Patient_0   71    Male           12/13-2023
# 1      PID1001    Patient_1   34    Male  2024-10-16 00:00:00
# 2      PID1010    Patient_2   57  Female       April 31, 2022
# 3      PID1100    Patient_3   24  Female           03/21/2024
# 4      PID1101    Patient_4   33    Male  2024-04-09 00:00:00
# ..         ...          ...  ...     ...                  ...
# 127    PID1095  Patient_127   54  Female           12/13-2023
# 128    PID1096  Patient_128   84    Male                  NaN
# 129    PID1097  Patient_129   66    Male  2024-07-03 00:00:00
# 130    PID1098  Patient_130   22    Male           18.10.2024
# 131    PID1099  Patient_131   20  Female  2023-04-25 00:00:00
#
#              Date_of_Diagnosis Date_of_Treatment_Start      Date_of_Surgery  \
# 0          2024-09-13 00:00:00                   42535  2018-03-13 00:00:00
# ...

# %%
# To clean and standardize data
def clean_date(val):
    if pd.isna(val):
        return np.nan
    try:
        if isinstance(val, (int, float)):
            return pd.to_datetime("1899-12-30") + pd.to_timedelta(val, unit="D")
        elif isinstance(val, str):
            val = val.replace("(estimated)", "").strip()
            return parser.parse(val, dayfirst=False, fuzzy=True)
        else:
            return pd.to_datetime(val, errors="coerce")
    except Exception:
        return np.nan

        # Clean all date columns
date_cols = [
    "Date_of_Admission",
    "Date_of_Diagnosis",
    "Date_of_Treatment_Start",
    "Date_of_Surgery",
    "Date_of_Discharge",
    "Follow_up_Visit"
]
for col in date_cols:
    df[col] = df[col].apply(clean_date)

    # Save cleaned data to new excel
df.to_excel("Cleaned_Patient_Data.xlsx", index=False)

# %%
import pandas as pd
import numpy as np

# %%
# Load file
df_clean = pd.read_excel("Cleaned_Patient_Data.xlsx")
df_clean
# Out:
#     Patient_ID         Name  Age  Gender Date_of_Admission Date_of_Diagnosis  \
# 0      PID1000    Patient_0   71    Male        2023-12-13        2024-09-13
# 1      PID1001    Patient_1   34    Male        2024-10-16        2023-08-05
# 2      PID1010    Patient_2   57  Female               NaT        2016-11-11
# 3      PID1100    Patient_3   24  Female        2024-03-21        2024-04-13
# 4      PID1101    Patient_4   33    Male        2024-04-09        2023-03-16
# ..         ...          ...  ...     ...               ...               ...
# 127    PID1095  Patient_127   54  Female        2023-12-13        2018-12-10
# 128    PID1096  Patient_128   84    Male               NaT        2017-11-26
# 129    PID1097  Patient_129   66    Male        2024-07-03        2017-11-26
# 130    PID1098  Patient_130   22    Male        2024-10-18        2016-11-18
# 131    PID1099  Patient_131   20  Female        2023-04-25        2023-05-15
#
# ...
